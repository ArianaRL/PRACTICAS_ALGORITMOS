# %%
print("Que tipo de conversion deseas:")
print("1.-Longitud")
print("2.-Temperatura")
print("3.-Masa")
print("4.-Volumen")
print("5.-Tiempo")
papas=int(input())
if(papas==1):
    print("Que unidades deseas convertir:")
    print("1.-cm/pulgadas")
    print("2.-m/pies")
    print("3.-m/pulgadas")
    print("4.-m/millas")
    print("5.-Km/yardas")
    print("6.-Km/millas")
    fritas=int(input())
    if(fritas==1):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad/2.54
        print("Resultado De cm a pulgadas es: ",x)
    
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
        
    elif(fritas==2):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*3.281
        print("Resultado De m a pies es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==3):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*39.37
        print("Resultado De m a pulgadas es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==4):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad/1609
        print("Resultado De m a millas es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
        
    elif(fritas==5):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*1094
        print("Resultado De Km a Yardas es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==6):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad/1.609
        print("Resultado De Km a millas es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
elif(papas==2):
    print("Que unidades deseas convertir:")
    print("1.-celsius/farenheit")
    print("2.-celsius/kelvin")
    print("3.-kelvin/farenheit")
    fritas=int(input())
    if(fritas==1):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=(cantidad(9/5))+32
        print(cantidad,"resultado De °C a Farenheit es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
        
    elif(fritas==2):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad+273.15
        print("Resultado De °C a Kelvin es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==3):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=((cantidad-273.15)*(9/5))+32
        print("Resultado De °K a Farenheit es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
        
elif(papas==3):
    print("Que unidades deseas convertir: ")
    print("1.-Kg/Libras")
    print("2.-Gramos/Onzas")
    print("3.-Kg/Toneladas")
    fritas=int(input())
    if(fritas==1):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*2.205
        print("Resultado De Kg a Libras es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==2):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad/28.35
        print("Resultado De g a Onzas es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==3):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad/1000
        print("Resultado De Kg a Toneladas es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
elif(papas==4):
    print("Que unidades deseas convertir: ")
    print("1.-litro/galon")
    print("2.-m^3/yd^3")
    print("3.-m^3/pulgada^3")
    print("3.-m^3/pies^3")
    fritas=int(input())
    if(fritas==1):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*3.785
        print("Resultado De lt a Galon es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==2):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*1.308
        print("Resultado De m^3 a Yd^3 es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==3):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*1.308
        print("Resultado De m^3 a pulgada^3 es: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==4):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*35.315
        print("Resultado De m^3 a pies^3 es: ",x)
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
elif(papas==5):
    print("Que unidades deseas convertir: ")
    print("1.-Horas/Minutos")
    print("2.-Minutos/Segundos")
    print("3.-Segundos/Milisegundos")
    fritas=int(input())
    if(fritas==1):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*60
        print("Resultado: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==2):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*60
        print("Resultado: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
        
    elif(fritas==3):
        print("Ingresa la cantidad a convertir: ")
        cantidad=float(input())
        x=cantidad*1000
        print("Resultado: ",x)
        
        f=open('Resultado De Conversiones.txt','a') #
        f.write(str(x))
        f.close()
# Out:
# Que tipo de conversion deseas:
# 1.-Longitud
# 2.-Temperatura
# 3.-Masa
# 4.-Volumen
# 5.-Tiempo
# 1
# Que unidades deseas convertir:
# 1.-cm/pulgadas
# 2.-m/pies
# 3.-m/pulgadas
# 4.-m/millas
# 5.-Km/yardas
# 6.-Km/millas
# 3
# Ingresa la cantidad a convertir:
# 5
# Resultado De m a pulgadas es:  196.85

# %%
#construir archivo 
f=open('papasfritas.txt','a') #
a=5
f.write(str(a))

f.write()



f.close()
# Out:
#   File "C:\Users\jesus\AppData\Local\Temp/ipykernel_1396/3122532475.py", line 4
#     f.write(resultado de Segundos a Milis(str(a))
#                       ^
# SyntaxError: invalid syntax
